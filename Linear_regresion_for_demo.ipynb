# %% [markdown]
# <a href="https://colab.research.google.com/github/dceaicovschi/Data_Science_and_Machine_Learning_Bootcamp/blob/master/Linear_regresion_for_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression

# %%
! wget https://github.com/anandb7248/Data_Science_and_Machine_Learning_Bootcamp/blob/master/2_Predict_Movie_Box_Office_Revenue_with_Linear_Regression/cost-revenue-clean.csv
# Out:
# --2021-07-14 16:47:37--  https://github.com/anandb7248/Data_Science_and_Machine_Learning_Bootcamp/blob/master/2_Predict_Movie_Box_Office_Revenue_with_Linear_Regression/cost-revenue-clean.csv
# Resolving github.com (github.com)... 192.30.255.113
# Connecting to github.com (github.com)|192.30.255.113|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘cost-revenue-clean.csv’
#
# cost-revenue-clean.     [    <=>             ]   1.15M  1.53MB/s    in 0.8s
#
# 2021-07-14 16:47:38 (1.53 MB/s) - ‘cost-revenue-clean.csv’ saved [1208898]

# %%
data = pd.read_csv("dataset.csv")
data
# Out:
#       production_budget_usd  worldwide_gross_usd
# 0                   1000000                   26
# 1                     10000                  401
# 2                    400000                  423
# 3                    750000                  450
# 4                     10000                  527
# ...                     ...                  ...
# 5029              225000000           1519479547
# 5030              215000000           1671640593
# 5031              306000000           2058662225
# 5032              200000000           2207615668
# 5033              425000000           2783918982
#
# [5034 rows x 2 columns]

# %%
data.describe()
# Out:
#        production_budget_usd  worldwide_gross_usd
# count           5.034000e+03         5.034000e+03
# mean            3.290784e+07         9.515685e+07
# std             4.112589e+07         1.726012e+08
# min             1.100000e+03         2.600000e+01
# 25%             6.000000e+06         7.000000e+06
# 50%             1.900000e+07         3.296202e+07
# 75%             4.200000e+07         1.034471e+08
# max             4.250000e+08         2.783919e+09

# %%
model= LinearRegression()

# %%
plt.figure(figsize=(15, 10))
plt.scatter(data.production_budget_usd, data.worldwide_gross_usd, alpha= 0.4)
plt.xlabel('Budget')
plt.ylabel('Revenue')
plt.ylim(0,3000000000)
plt.xlim(0,450000000)
# Out:
# (0.0, 450000000.0)

# %%
X=pd.DataFrame(data.production_budget_usd)
Y=pd.DataFrame(data.worldwide_gross_usd)

# %%
model.fit(X,Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
model.coef_
# Out:
# array([[3.11150918]])

# %%
model.intercept_
# Out:
# array([-7236192.72913958])

# %%
plt.figure(figsize=(15, 10))
plt.scatter(data.production_budget_usd, data.worldwide_gross_usd, alpha= 0.4)

plt.plot(X, model.predict(X), color ='red')

plt.xlabel('Budget')
plt.ylabel('Revenue')
plt.ylim(0,3000000000)
plt.xlim(0,450000000)
# Out:
# (0.0, 450000000.0)

# %%
model.score(X, Y)
# Out:
# 0.5496485356985729

# %%
model.predict([[5000000]])
# Out:
# array([[8321353.18554105]])
